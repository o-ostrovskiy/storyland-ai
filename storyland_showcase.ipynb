# %% [markdown]
# # StoryLand AI - Complete Feature Showcase
#
# **Transform books into travel adventures using Google Agent Development Kit (ADK)**
#
# This notebook demonstrates a production-ready multi-agent system that showcases:
#
# ## 🎯 Features Demonstrated
#
# ### Multi-Agent Architecture
# - ✅ **Sequential Agents** - Metadata → Discovery → Composition workflow
# - ✅ **Parallel Agents** - Concurrent city, landmark, and author discovery
# - ✅ **LLM-Powered** - All agents powered by Gemini 2.0 Flash
# - ✅ **Three-Phase Workflow** - Metadata extraction, discovery with region analysis, and composition
#
# ### Tools & Integration
# - ✅ **Custom Tools** - Google Books API integration, user preferences tool
# - ✅ **Built-in Tools** - Google Search for research
# - ✅ **Pydantic Models** - Type-safe agent communication
#
# ### Sessions & State Management
# - ✅ **InMemorySessionService** - Fast development and testing
# - ✅ **DatabaseSessionService** - SQLite persistence across restarts
# - ✅ **Multi-Scoped State** - Session, user, app, and temporary scopes
# - ✅ **User Preferences** - Persistent across sessions with `user:` prefix
#
# ### Context Engineering
# - ✅ **ContextManager** - Automatic context size monitoring
# - ✅ **Sliding Window** - Keep recent events when context grows too large
# - ✅ **Token Tracking** - Estimate and limit token usage
#
# ### Observability
# - ✅ **Structured Logging** - Detailed execution logs with structlog
# - ✅ **ADK LoggingPlugin** - Built-in agent observability
# - ✅ **Event Tracking** - Monitor agent execution flow
#
# ### Evaluation
# - ✅ **ADK Eval** - Automated rubric-based evaluation
# - ✅ **Custom Rubrics** - Book relevance, preference adherence, completeness, etc.
#
# ### Advanced Features
# - ✅ **Human-in-the-Loop** - Region selection for practical travel planning
# - ✅ **Geographic Grouping** - LLM-based region analysis
# - ✅ **Multi-User Support** - Isolated sessions and preferences per user
#
# ---
#
# ## 📚 What You'll Build
#
# By the end of this notebook, you'll have executed a complete literary travel planning system that:
# 1. Extracts exact book metadata from Google Books API
# 2. Discovers cities, landmarks, and author-related sites
# 3. Groups locations into practical travel regions
# 4. Lets you select which regions to explore (HITL)
# 5. Creates a personalized itinerary based on your preferences
#
# All with full observability, persistent sessions, and type-safe communication!

# %% [markdown]
# ## 🔧 Setup & Configuration

# %%
# Standard library imports
import os
import sys
import json
import uuid
import logging
from datetime import datetime
from dotenv import load_dotenv

# Google ADK imports
from google.genai import types
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner
from google.adk.plugins.logging_plugin import LoggingPlugin

# StoryLand AI imports
from services.session_service import create_session_service
from services.context_manager import ContextManager
from tools.google_books import google_books_tool
from agents.orchestrator import (
    create_metadata_stage,
    create_discovery_workflow,
    create_composition_workflow,
    create_eval_workflow,
)
from common.logging import configure_logging, get_logger

# Load environment
load_dotenv()

# Configure logging
configure_logging(level="INFO")
logger = get_logger(__name__)

print("✅ Environment Setup Complete")
print(f"   Google API Key: {'✓ Found' if os.getenv('GOOGLE_API_KEY') else '✗ MISSING'}")
print(f"   Python: {sys.version.split()[0]}")
print(f"   Logging: INFO level")
# Out:
# ✅ Environment Setup Complete
#    Google API Key: ✓ Found
#    Python: 3.12.6
#    Logging: INFO level

# %% [markdown]
# ## 🎨 Section 1: Pydantic Data Models
#
# StoryLand AI uses **Pydantic models** for type-safe agent communication. Each agent's output is validated against a schema, ensuring data quality and catching errors early.
#
# ### Benefits:
# - **Type Safety** - Automatic validation of all fields
# - **Clear Contracts** - Each agent knows exactly what to produce
# - **Better Debugging** - Detailed validation error messages
# - **IDE Support** - Autocomplete and type hints

# %%
from models.book import BookMetadata, BookContext
from models.discovery import (
    CityDiscovery, 
    LandmarkDiscovery, 
    AuthorSites,
    RegionAnalysis,  # NEW: Region grouping
)
from models.itinerary import TripItinerary, CityPlan, CityStop
from models.preferences import TravelPreferences

print("📦 Pydantic Models Loaded:")
print("\n   Book Models:")
print("     - BookMetadata (title, author, description, etc.)")
print("     - BookContext (locations, time_period, themes)")
print("\n   Discovery Models:")
print("     - CityDiscovery (list of cities with relevance)")
print("     - LandmarkDiscovery (list of landmarks with connections)")
print("     - AuthorSites (museums, birthplaces, etc.)")
print("     - RegionAnalysis (geographic grouping of cities) ⭐ NEW")
print("\n   Itinerary Models:")
print("     - TripItinerary (cities list + summary)")
print("     - CityPlan (city + days + stops)")
print("     - CityStop (name, type, reason, time_of_day, notes)")
print("\n   Preferences Model:")
print("     - TravelPreferences (budget, pace, museums, kids, etc.)")

# Show an example schema
print("\n📋 Example: CityStop Schema")
print(json.dumps(CityStop.model_json_schema(), indent=2)[:500] + "...")
# Out:
# 📦 Pydantic Models Loaded:
#
#    Book Models:
#      - BookMetadata (title, author, description, etc.)
#      - BookContext (locations, time_period, themes)
#
#    Discovery Models:
#      - CityDiscovery (list of cities with relevance)
#      - LandmarkDiscovery (list of landmarks with connections)
#      - AuthorSites (museums, birthplaces, etc.)
#      - RegionAnalysis (geographic grouping of cities) ⭐ NEW
#
#    Itinerary Models:
#      - TripItinerary (cities list + summary)
#      - CityPlan (city + days + stops)
#      - CityStop (name, type, reason, time_of_day, notes)
#
#    Preferences Model:
#      - TravelPreferences (budget, pace, museums, kids, etc.)
#
# 📋 Example: CityStop Schema
# {
#   "description": "A stop/place to visit in a city",
#   "properties": {
#     "name": {
#       "description": "Name of the place",
#       "title": "Name",
#       "type": "string"
#     },
#     "type": {
#       "description": "Type: landmark, museum, cafe, restaurant, bookstore, etc.",
#       "title": "Type",
#       "type": "string"
#     },
#     "reason": {
#       "description": "Why this place matters for the book",
#       "title": "Reason",
#       "type": "string"
#     },
#     "time_of_day": {
#       "description...

# %% [markdown]
# ## 🤖 Section 2: Custom Tools
#
# StoryLand AI uses custom tools to integrate with external APIs:
#
# ### 1. Google Books Tool
# Searches Google Books API and returns Pydantic-validated book metadata.
#
# ### 2. Preferences Tool
# Reads user preferences from session state (using `ToolContext.state`).

# %%
from tools.google_books import search_book
from tools.preferences import get_user_preferences

print("🔧 Custom Tools:")
print("\n   1. google_books_tool")
print("      Function: search_book(title, author)")
print("      Returns: BookMetadata JSON")
print("      Purpose: Search Google Books API")

print("\n   2. get_preferences_tool")
print("      Function: get_preferences()")
print("      Returns: User preferences from session state")
print("      Purpose: Access user:preferences via ToolContext")

# Demonstrate google_books_tool
print("\n📚 Demo: Search for 'Pride and Prejudice'")
try:
    result_json = search_book(title="Pride and Prejudice", author="Jane Austen")
    result = json.loads(result_json)
    print(f"\n   ✅ Found: {result.get('book_title')}")
    print(f"      Author: {result.get('author')}")
    print(f"      Published: {result.get('published_date')}")
    print(f"      Categories: {', '.join(result.get('categories', [])[:3])}")
except Exception as e:
    print(f"\n   ⚠️  Error: {e}")
    print("      (This is expected if no internet connection)")
# Out:
# 🔧 Custom Tools:
#
#    1. google_books_tool
#       Function: search_book(title, author)
#       Returns: BookMetadata JSON
#       Purpose: Search Google Books API
#
#    2. get_preferences_tool
#       Function: get_preferences()
#       Returns: User preferences from session state
#       Purpose: Access user:preferences via ToolContext
#
# 📚 Demo: Search for 'Pride and Prejudice'
# 2025-11-25 21:44:27 [info     ] search_book_called             author='Jane Austen' title='Pride and Prejudice'
# 2025-11-25 21:44:27 [info     ] google_books_search            author='Jane Austen' title='Pride and Prejudice'
# 2025-11-25 21:44:27 [info     ] google_books_results           count=5
# 2025-11-25 21:44:27 [info     ] google_books_selected          author='Jane Austen' title='Pride and Prejudice'
#
#    ✅ Found: Pride and Prejudice
#       Author: Jane Austen
#       Published: 1918
#       Categories: Courtship

# %% [markdown]
# ## 🏗️ Section 3: Multi-Agent Architecture
#
# StoryLand AI uses a **three-phase workflow** with multiple agent types:
#
# ### Phase 1: Metadata Stage
# - Extracts exact book title and author from Google Books API
# - **Why?** Books like "The Nightingale" can match multiple books
#
# ### Phase 2: Discovery Workflow
# - **Sequential agents**: book_context → reader_profile
# - **Parallel agents**: city_discovery, landmark_discovery, author_sites (concurrent)
# - **Region analyzer**: Groups cities into practical travel regions
#
# ### Phase 3: Composition Workflow
# - Creates itinerary for user-selected region(s)
# - Personalized based on preferences
#
# ### Agent Types:
# - **SequentialAgent** - Executes sub-agents in order
# - **ParallelAgent** - Runs sub-agents concurrently
# - **LlmAgent** - Single LLM-powered agent with tools/output_schema

# %%
# Configure Gemini model
retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

model = Gemini(
    model=os.getenv("MODEL_NAME", "gemini-2.0-flash-lite"),
    api_key=os.getenv("GOOGLE_API_KEY"),
    retry_options=retry_config,
)

print(f"🤖 Model Configured: {model.model}")
print(f"   Retry attempts: 5")
print(f"   Exponential backoff: enabled")

# Create the three-phase workflow stages
print("\n🏗️  Creating Three-Phase Workflow:")

# Phase 1: Metadata extraction
metadata_stage = create_metadata_stage(model, google_books_tool)
print("\n   ✅ Phase 1: Metadata Stage")
print("      - Searches Google Books API")
print("      - Extracts exact title and author")
print("      - Saves to state['book_metadata']")

# Phase 2: Discovery (will be created per-book)
print("\n   ✅ Phase 2: Discovery Workflow (created per book)")
print("      - book_context_pipeline (researches setting)")
print("      - reader_profile_agent (loads preferences)")
print("      - ParallelAgent (city, landmark, author) ⚡ concurrent")
print("      - region_analyzer_agent (groups cities by geography)")
print("      - Saves to state['region_analysis']")

# Phase 3: Composition (created separately)
print("\n   ✅ Phase 3: Composition Workflow")
print("      - trip_composer_agent (creates itinerary)")
print("      - Uses selected region(s) from HITL")
print("      - Saves to state['final_itinerary']")

# Also show eval workflow for reference
print("\n   📊 Bonus: Eval Workflow (for automated testing)")
print("      - Combines all 6 stages")
print("      - Auto-selects all regions (no HITL)")
print("      - Used for ADK eval with rubrics")
# Out:
# 🤖 Model Configured: gemini-2.5-flash
#    Retry attempts: 5
#    Exponential backoff: enabled
#
# 🏗️  Creating Three-Phase Workflow:
#
#    ✅ Phase 1: Metadata Stage
#       - Searches Google Books API
#       - Extracts exact title and author
#       - Saves to state['book_metadata']
#
#    ✅ Phase 2: Discovery Workflow (created per book)
#       - book_context_pipeline (researches setting)
#       - reader_profile_agent (loads preferences)
#       - ParallelAgent (city, landmark, author) ⚡ concurrent
#       - region_analyzer_agent (groups cities by geography)
#       - Saves to state['region_analysis']
#
#    ✅ Phase 3: Composition Workflow
#       - trip_composer_agent (creates itinerary)
#       - Uses selected region(s) from HITL
#       - Saves to state['final_itinerary']
#
#    📊 Bonus: Eval Workflow (for automated testing)
#       - Combines all 6 stages
#       - Auto-selects all regions (no HITL)
#       - Used for ADK eval with rubrics

# %% [markdown]
# ## 💾 Section 4: Sessions & State Management
#
# ADK provides flexible session management:
#
# ### InMemorySessionService
# - Fast, perfect for development
# - Sessions lost on restart
#
# ### DatabaseSessionService (SQLite)
# - Persistent across restarts
# - Enables analytics and user profiling
#
# ### State Scopes:
# - **Session scope** (`state["key"]`) - Per conversation
# - **User scope** (`state["user:key"]`) - Persists across all user sessions
# - **App scope** (`state["app:key"]`) - Global for all users
# - **Temporary scope** (`state["temp:key"]`) - Never persisted

# %%
# Choose session service type
USE_DATABASE = True  # Set to False for in-memory only

session_service = create_session_service(use_database=USE_DATABASE)

print(f"💾 Session Service: {'DatabaseSessionService (SQLite)' if USE_DATABASE else 'InMemorySessionService'}")
if USE_DATABASE:
    print("   Database: storyland_sessions.db")
    print("   ✅ Sessions persist across restarts")
    print("   ✅ User preferences persist")
    print("   ✅ Can query with SQL")
else:
    print("   ⚠️  Sessions lost on restart")
    print("   ✅ Fast for development")

print("\n📊 State Scopes:")
print("   - state['key']         → Session scope (per conversation)")
print("   - state['user:key']    → User scope (persists across sessions)")
print("   - state['app:key']     → App scope (global for all users)")
print("   - state['temp:key']    → Temporary (never persisted)")
# Out:
# Using DatabaseSessionService with: sqlite:///storyland_sessions.db
# 2025-11-25 16:44:27 - google_adk.google.adk.sessions.database_session_service - INFO - Local timezone: America/New_York
# 💾 Session Service: DatabaseSessionService (SQLite)
#    Database: storyland_sessions.db
#    ✅ Sessions persist across restarts
#    ✅ User preferences persist
#    ✅ Can query with SQL
#
# 📊 State Scopes:
#    - state['key']         → Session scope (per conversation)
#    - state['user:key']    → User scope (persists across sessions)
#    - state['app:key']     → App scope (global for all users)
#    - state['temp:key']    → Temporary (never persisted)

# %% [markdown]
# ## 👤 Section 5: User Preferences & Personalization
#
# User preferences are stored in `state["user:preferences"]` and persist across sessions.
#
# ### How it works:
# 1. User preferences set in session state
# 2. `reader_profile_agent` calls `get_preferences_tool`
# 3. Tool reads from `ToolContext.state["user:preferences"]`
# 4. `trip_composer_agent` sees preferences summary
# 5. Itinerary is personalized

# %%
# Define user preferences
user_id = "demo_user"
session_id = str(uuid.uuid4())

user_preferences = {
    "budget": "moderate",           # budget, moderate, luxury
    "preferred_pace": "relaxed",    # relaxed, moderate, fast-paced
    "prefers_museums": True,
    "travels_with_kids": False,
    "dietary_restrictions": ["vegetarian"],
    "favorite_genres": ["historical fiction", "classics"],
}

print("👤 User Preferences:")
print(json.dumps(user_preferences, indent=2))
print("\n   These will be stored as state['user:preferences']")
print("   They persist across all sessions for this user!")
# Out:
# 👤 User Preferences:
# {
#   "budget": "moderate",
#   "preferred_pace": "relaxed",
#   "prefers_museums": true,
#   "travels_with_kids": false,
#   "dietary_restrictions": [
#     "vegetarian"
#   ],
#   "favorite_genres": [
#     "historical fiction",
#     "classics"
#   ]
# }
#
#    These will be stored as state['user:preferences']
#    They persist across all sessions for this user!

# %% [markdown]
# ## 🎯 Section 6: Context Engineering
#
# The `ContextManager` monitors conversation size and applies compaction when needed.
#
# ### Features:
# - **Token Estimation** - Approximate token count from text length
# - **Event Limiting** - Keep only recent N events (sliding window)
# - **Compaction Detection** - Automatically detect when to compact
# - **System Prompt Preservation** - Keep important system messages

# %%
# Create context manager with limits
context_manager = ContextManager(
    max_events=20,        # Keep max 20 events
    max_tokens=30000,     # Approximate token limit
    preserve_system=True  # Always keep system prompts
)

print("🎯 Context Manager Configuration:")
print(f"   Max events: {context_manager.max_events}")
print(f"   Max tokens: {context_manager.max_tokens:,}")
print(f"   Preserve system prompts: {context_manager.preserve_system}")

# Demo: Simulate a long conversation
from google.genai import types

class MockEvent:
    def __init__(self, text):
        self.content = types.Content(parts=[types.Part(text=text)])

# Create mock conversation
mock_events = [MockEvent(f"Event {i}: {'x' * 100}") for i in range(25)]

# Get statistics
stats = context_manager.get_context_stats(mock_events)
print(f"\n📊 Example Conversation:")
print(f"   Total events: {stats['num_events']}")
print(f"   Total characters: {stats['total_chars']:,}")
print(f"   Estimated tokens: ~{stats['estimated_tokens']}")
print(f"   Within limits: {stats['within_limit']}")

# Show compaction
if context_manager.should_compact(mock_events):
    compacted = context_manager.limit_events(mock_events, num_recent=15)
    after_stats = context_manager.get_context_stats(compacted)
    
    print(f"\n🗜️  After Compaction:")
    print(f"   Events: {len(mock_events)} → {len(compacted)}")
    print(f"   Tokens: ~{stats['estimated_tokens']} → ~{after_stats['estimated_tokens']}")
    print(f"   Saved: ~{stats['estimated_tokens'] - after_stats['estimated_tokens']} tokens")
# Out:
# 🎯 Context Manager Configuration:
#    Max events: 20
#    Max tokens: 30,000
#    Preserve system prompts: True
#
# 📊 Example Conversation:
#    Total events: 25
#    Total characters: 2,740
#    Estimated tokens: ~685
#    Within limits: False
#
# 🗜️  After Compaction:
#    Events: 25 → 15
#    Tokens: ~685 → ~412
#    Saved: ~273 tokens

# %% [markdown]
# ## 📝 Section 7: Observability - Logging
#
# StoryLand AI uses multiple logging layers:
#
# ### 1. Structured Logging (structlog)
# - Key-value logging for easy parsing
# - Defined in `common/logging.py`
#
# ### 2. ADK LoggingPlugin
# - Built-in agent observability
# - Tracks agent execution, tool calls, etc.
#
# ### 3. Event Monitoring
# - Track each agent's output via `runner.run_async()`

# %%
from common.logging import get_logger

# Get a structured logger
demo_logger = get_logger("showcase_demo")

print("📝 Logging Configuration:")
print("\n   1. Structured Logging (structlog)")
demo_logger.info("example_event", user_id="demo_user", action="showcase", count=42)
print("      ↑ Notice: key=value format")

print("\n   2. ADK LoggingPlugin")
print("      - Automatically logs agent execution")
print("      - Tool calls and responses")
print("      - Model interactions")

print("\n   3. Event Monitoring")
print("      - Track via runner.run_async()")
print("      - Shows agent names, tool calls, responses")
print("      - Detect final responses with event.is_final_response()")
# Out:
# 📝 Logging Configuration:
#
#    1. Structured Logging (structlog)
# 2025-11-25 21:44:27 [info     ] example_event                  action=showcase count=42 user_id=demo_user
#       ↑ Notice: key=value format
#
#    2. ADK LoggingPlugin
#       - Automatically logs agent execution
#       - Tool calls and responses
#       - Model interactions
#
#    3. Event Monitoring
#       - Track via runner.run_async()
#       - Shows agent names, tool calls, responses
#       - Detect final responses with event.is_final_response()

# %% [markdown]
# ## 📊 Section 8: Agent Evaluation
#
# StoryLand AI uses **ADK Eval** for automated testing with rubric-based scoring.
#
# ### Evaluation Rubrics:
# - `book_relevance` - Locations connected to book
# - `preference_adherence` - Respects user preferences
# - `completeness` - Comprehensive itinerary
# - `actionability` - Practical details
# - `geographical_accuracy` - Real places, correct countries
#
# ### Running Evals:
# ```bash
# .venv/bin/adk eval agents/storyland single_test \
#   --config_file_path tests/evaluation/eval_config.json \
#   --print_detailed_results
# ```

# %%
import os
from pathlib import Path

# Check if eval config exists
eval_config_path = Path("tests/evaluation/eval_config.json")

print("📊 Agent Evaluation:")
print(f"\n   Config file: {eval_config_path}")
print(f"   Exists: {eval_config_path.exists()}")

if eval_config_path.exists():
    with open(eval_config_path) as f:
        eval_config = json.load(f)
    
    print(f"\n   Rubrics defined: {len(eval_config.get('rubrics', []))}")
    print("\n   Rubric Details:")
    for rubric in eval_config.get('rubrics', []):
        print(f"     - {rubric.get('name')}: {rubric.get('description', '')[:60]}...")

print("\n   💡 Run evals with:")
print("      .venv/bin/adk eval agents/storyland single_test \\")
print("        --config_file_path tests/evaluation/eval_config.json \\")
print("        --print_detailed_results")

print("\n   🎯 Uses create_eval_workflow() which auto-selects all regions")
# Out:
# 📊 Agent Evaluation:
#
#    Config file: tests/evaluation/eval_config.json
#    Exists: True
#
#    Rubrics defined: 0
#
#    Rubric Details:
#
#    💡 Run evals with:
#       .venv/bin/adk eval agents/storyland single_test \
#         --config_file_path tests/evaluation/eval_config.json \
#         --print_detailed_results
#
#    🎯 Uses create_eval_workflow() which auto-selects all regions

# %% [markdown]
# ## 🚀 Section 9: Full End-to-End Demo
#
# Now let's run the complete three-phase workflow:
#
# 1. **Phase 1**: Extract exact book metadata
# 2. **Phase 2**: Discover locations and analyze regions
# 3. **Human-in-the-Loop**: Select regions (simulated)
# 4. **Phase 3**: Create personalized itinerary
#
# ### Configure Your Book Here:

# %%
# ============================================================
# CONFIGURE YOUR BOOK AND PREFERENCES HERE
# ============================================================
BOOK_TITLE = "Pride and Prejudice"
AUTHOR = "Jane Austen"  # Optional

# User preferences (customize these!)
USER_PREFERENCES = {
    "budget": "moderate",
    "preferred_pace": "relaxed",
    "prefers_museums": True,
    "travels_with_kids": False,
}
# ============================================================

print(f"📚 Book: {BOOK_TITLE}")
print(f"   Author: {AUTHOR or 'Unknown'}")
print(f"\n👤 Preferences:")
for key, value in USER_PREFERENCES.items():
    print(f"   - {key}: {value}")
# Out:
# 📚 Book: Pride and Prejudice
#    Author: Jane Austen
#
# 👤 Preferences:
#    - budget: moderate
#    - preferred_pace: relaxed
#    - prefers_museums: True
#    - travels_with_kids: False

# %% [markdown]
# ### Create Session with Preferences

# %%
# Create session
user_id = "demo_user"
session_id = str(uuid.uuid4())

await session_service.create_session(
    app_name="storyland",
    user_id=user_id,
    session_id=session_id,
    state={
        "user:preferences": USER_PREFERENCES  # Persists across sessions!
    },
)

print(f"✅ Session Created")
print(f"   User ID: {user_id}")
print(f"   Session ID: {session_id[:8]}...")
print(f"   Preferences stored in state['user:preferences']")
# Out:
# ✅ Session Created
#    User ID: demo_user
#    Session ID: d1545072...
#    Preferences stored in state['user:preferences']

# %% [markdown]
# ### Phase 1: Extract Book Metadata

# %%
print("="*70)
print("PHASE 1: EXTRACT BOOK METADATA")
print("="*70)

# Create runner for metadata stage
metadata_runner = Runner(
    agent=metadata_stage,
    app_name="storyland",
    session_service=session_service,
    plugins=[LoggingPlugin()],
)

metadata_prompt = f'Find book metadata for "{BOOK_TITLE}" by {AUTHOR or "unknown author"}.'
metadata_message = types.Content(role="user", parts=[types.Part(text=metadata_prompt)])

print(f"\n📝 Prompt: {metadata_prompt}")
print(f"\n🔄 Executing metadata extraction...\n")

event_count = 0
async with metadata_runner:
    async for event in metadata_runner.run_async(
        user_id=user_id, session_id=session_id, new_message=metadata_message
    ):
        event_count += 1
        if event.author:
            print(f"[{event_count}] {event.author}")

# Get metadata from session state
session = await session_service.get_session(
    app_name="storyland", user_id=user_id, session_id=session_id
)
book_metadata = session.state.get("book_metadata", {})
exact_title = book_metadata.get("book_title", BOOK_TITLE)
exact_author = book_metadata.get("author", AUTHOR or "Unknown")

print(f"\n✅ Metadata extracted!")
print(f"   Exact title: {exact_title}")
print(f"   Exact author: {exact_author}")
print(f"   Published: {book_metadata.get('published_date', 'N/A')}")
# Out:
# ======================================================================
# PHASE 1: EXTRACT BOOK METADATA
# ======================================================================
# 2025-11-25 16:44:28 - google_adk.google.adk.plugins.plugin_manager - INFO - Plugin 'logging_plugin' registered.
# 2025-11-25 16:44:28 - google_adk.google.adk.runners - WARNING - App name mismatch detected. The runner is configured with app name "storyland", but the root agent was loaded from "/Users/osa/Documents/storyland/storyland-ai/.venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
#
# 📝 Prompt: Find book metadata for "Pride and Prejudice" by Jane Austen.
#
# 🔄 Executing metadata extraction...
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin]    Session ID: d1545072-e8e2-4719-b94e-7a496081bcb4
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: storyland
# [logging_plugin]    Root Agent: metadata_stage
# [logging_plugin]    User Content: text: 'Find book metadata for "Pride and Prejudice" by Jane Austen.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin]    Starting Agent: metadata_stage
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: metadata_stage
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_metadata_pipeline
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_metadata_researcher
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    System Instruction: 'You are a book metadata specialist. Extract complete book information.
#
# 1. Use the search_book tool with BOTH title AND author parameters when available
#    - If user provides "The Great Gatsby by F. S...'
# [logging_plugin]    Available Tools: ['search_book']
# 2025-11-25 16:44:28 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:29 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# 2025-11-25 16:44:29 - google_genai.types - WARNING - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    Content: function_call: search_book
# [logging_plugin]    Token Usage - Input: 330, Output: 23
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 129dc74f-6836-4b7f-a7bf-8a09e3b37ae8
# [logging_plugin]    Author: book_metadata_researcher
# [logging_plugin]    Content: function_call: search_book
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['search_book']
# [1] book_metadata_researcher
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: search_book
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    Function Call ID: adk-aab4d0fc-4bcb-4d29-856e-b489fd9f04a0
# [logging_plugin]    Arguments: {'author': 'Jane Austen', 'title': 'Pride and Prejudice'}
# 2025-11-25 21:44:29 [info     ] search_book_called             author='Jane Austen' title='Pride and Prejudice'
# 2025-11-25 21:44:29 [info     ] google_books_search            author='Jane Austen' title='Pride and Prejudice'
# 2025-11-25 21:44:29 [info     ] google_books_results           count=5
# 2025-11-25 21:44:29 [info     ] google_books_selected          author='Jane Austen' title='Pride and Prejudice'
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: search_book
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    Function Call ID: adk-aab4d0fc-4bcb-4d29-856e-b489fd9f04a0
# [logging_plugin]    Result: {"book_title":"Pride and Prejudice","author":"Jane Austen","description":"Austen’s most celebrated novel tells the story of Elizabeth Bennet, a bright, lively young woman with four sisters, and a mother determined to marry them to wealthy men. At a party near the Bennets’ home in the English country...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9d4b74c4-3ca5-47da-8809-77dee7efacc1
# [logging_plugin]    Author: book_metadata_researcher
# [logging_plugin]    Content: function_response: search_book
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['search_book']
# [2] book_metadata_researcher
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    System Instruction: 'You are a book metadata specialist. Extract complete book information.
#
# 1. Use the search_book tool with BOTH title AND author parameters when available
#    - If user provides "The Great Gatsby by F. S...'
# [logging_plugin]    Available Tools: ['search_book']
# 2025-11-25 16:44:29 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:30 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: book_metadata_researcher
# [logging_plugin]    Content: text: '{"book_title":"Pride and Prejudice","author":"Jane Austen","description":"Austen’s most celebrated novel tells the story of Elizabeth Bennet, a bright, lively young woman with four sisters, and a moth...'
# [logging_plugin]    Token Usage - Input: 584, Output: 211
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4e159bb5-97f0-4a27-bdf1-78aae01bb604
# [logging_plugin]    Author: book_metadata_researcher
# [logging_plugin]    Content: text: '{"book_title":"Pride and Prejudice","author":"Jane Austen","description":"Austen’s most celebrated novel tells the story of Elizabeth Bennet, a bright, lively young woman with four sisters, and a moth...'
# [logging_plugin]    Final Response: True
# [3] book_metadata_researcher
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_metadata_researcher
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_metadata_formatter
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: book_metadata_formatter
# [logging_plugin]    System Instruction: 'Format the book metadata into a validated BookMetadata object.
#
# IMPORTANT: If the researcher found no book or reported an error, return empty/null fields - do not hallucinate metadata.
#
# Extract from t...'
# 2025-11-25 16:44:30 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:30 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:44:33 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: book_metadata_formatter
# [logging_plugin]    Content: text: '{"book_title":"Pride and Prejudice","author":"Jane Austen","description":"Austen’s most celebrated novel tells the story of Elizabeth Bennet, a bright, lively young woman with four sisters, and a moth...'
# [logging_plugin]    Token Usage - Input: 645, Output: 211
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 05951a55-0545-4049-9b54-83e5a877ca68
# [logging_plugin]    Author: book_metadata_formatter
# [logging_plugin]    Content: text: '{"book_title":"Pride and Prejudice","author":"Jane Austen","description":"Austen’s most celebrated novel tells the story of Elizabeth Bennet, a bright, lively young woman with four sisters, and a moth...'
# [logging_plugin]    Final Response: True
# [4] book_metadata_formatter
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_metadata_formatter
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_metadata_pipeline
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: metadata_stage
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-43a3bf7d-ed12-4c00-abb2-32c2fc7acd73
# [logging_plugin]    Final Agent: metadata_stage
#
# ✅ Metadata extracted!
#    Exact title: Pride and Prejudice
#    Exact author: Jane Austen
#    Published: 1918

# %% [markdown]
# ### Phase 2: Discovery + Region Analysis

# %%
print("="*70)
print("PHASE 2: DISCOVERY + REGION ANALYSIS")
print("="*70)

# Create discovery workflow with exact book info
discovery_workflow = create_discovery_workflow(model, book_title=exact_title, author=exact_author)

discovery_runner = Runner(
    agent=discovery_workflow,
    app_name="storyland",
    session_service=session_service,
    plugins=[LoggingPlugin()],
)

discovery_prompt = f'Discover travel locations for "{exact_title}" by {exact_author}.\n\nFind cities, landmarks, and author-related sites, then group them into practical travel regions.'
discovery_message = types.Content(role="user", parts=[types.Part(text=discovery_prompt)])

print(f"\n📝 Prompt: Discover locations and group into regions")
print(f"\n🔄 Executing discovery workflow...\n")

async with discovery_runner:
    async for event in discovery_runner.run_async(
        user_id=user_id, session_id=session_id, new_message=discovery_message
    ):
        event_count += 1
        if event.author:
            print(f"[{event_count}] {event.author}")

# Get region analysis from session state
session = await session_service.get_session(
    app_name="storyland", user_id=user_id, session_id=session_id
)
region_analysis = session.state.get("region_analysis", {})

print(f"\n✅ Discovery complete!")
print(f"   Regions found: {len(region_analysis.get('regions', []))}")
# Out:
# ======================================================================
# PHASE 2: DISCOVERY + REGION ANALYSIS
# ======================================================================
# 2025-11-25 16:44:33 - google_adk.google.adk.plugins.plugin_manager - INFO - Plugin 'logging_plugin' registered.
# 2025-11-25 16:44:33 - google_adk.google.adk.runners - WARNING - App name mismatch detected. The runner is configured with app name "storyland", but the root agent was loaded from "/Users/osa/Documents/storyland/storyland-ai/.venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
#
# 📝 Prompt: Discover locations and group into regions
#
# 🔄 Executing discovery workflow...
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Session ID: d1545072-e8e2-4719-b94e-7a496081bcb4
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: storyland
# [logging_plugin]    Root Agent: discovery_workflow
# [logging_plugin]    User Content: text: 'Discover travel locations for "Pride and Prejudice" by Jane Austen.
#
# Find cities, landmarks, and author-related sites, then group them into practical travel regions.'
# 2025-11-25 16:44:33 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_formatter, event id: 05951a55-0545-4049-9b54-83e5a877ca68
# 2025-11-25 16:44:33 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 4e159bb5-97f0-4a27-bdf1-78aae01bb604
# 2025-11-25 16:44:33 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 9d4b74c4-3ca5-47da-8809-77dee7efacc1
# 2025-11-25 16:44:33 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 129dc74f-6836-4b7f-a7bf-8a09e3b37ae8
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Starting Agent: discovery_workflow
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: discovery_workflow
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_context_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_context_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: book_context_researcher
# [logging_plugin]    System Instruction: 'You are a literary research specialist. Research the book's setting and themes.
#
# BOOK: "Pride and Prejudice" by Jane Austen
#
# Use google_search to find:
# 1. PRIMARY LOCATIONS: Where does the story take ...'
# 2025-11-25 16:44:33 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:33 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:44:46 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: book_context_researcher
# [logging_plugin]    Content: text: '"Pride and Prejudice" by Jane Austen is set in early 19th-century England, primarily during the Regency Era (1811-1820). This period was characterized by significant social, political, and economic ch...'
# [logging_plugin]    Token Usage - Input: 943, Output: 1094
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 94a7561a-39bd-4a6d-aa84-61bf957fe93d
# [logging_plugin]    Author: book_context_researcher
# [logging_plugin]    Content: text: '"Pride and Prejudice" by Jane Austen is set in early 19th-century England, primarily during the Regency Era (1811-1820). This period was characterized by significant social, political, and economic ch...'
# [logging_plugin]    Final Response: True
# [5] book_context_researcher
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_context_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: book_context_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: book_context_formatter
# [logging_plugin]    System Instruction: 'Format the research into a validated BookContext object.
#
# IMPORTANT: If the research found no context information, return empty lists/null fields - do not hallucinate.
#
# Extract:
# - primary_locations: L...'
# 2025-11-25 16:44:46 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:46 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:44:49 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: book_context_formatter
# [logging_plugin]    Content: text: '{"primary_locations": ["Hertfordshire", "Longbourn", "Meryton", "Netherfield Park", "Kent", "Hunsford", "Rosings Park", "Derbyshire", "Pemberley", "London"], "time_period": "Regency Era (1811-1820)", ...'
# [logging_plugin]    Token Usage - Input: 1957, Output: 113
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: feb7346a-f3df-481b-86b3-b2b4ab27a07c
# [logging_plugin]    Author: book_context_formatter
# [logging_plugin]    Content: text: '{"primary_locations": ["Hertfordshire", "Longbourn", "Meryton", "Netherfield Park", "Kent", "Hunsford", "Rosings Park", "Derbyshire", "Pemberley", "London"], "time_period": "Regency Era (1811-1820)", ...'
# [logging_plugin]    Final Response: True
# [6] book_context_formatter
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_context_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: book_context_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: reader_profile_agent
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    System Instruction: 'You are a reader profile specialist focused on personalization.
#
# FIRST, call the get_user_preferences tool to retrieve user preferences from session state.
#
# The preferences may include:
# - budget: "bud...'
# [logging_plugin]    Available Tools: ['get_user_preferences']
# 2025-11-25 16:44:49 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:50 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# 2025-11-25 16:44:50 - google_genai.types - WARNING - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    Content: function_call: get_user_preferences
# [logging_plugin]    Token Usage - Input: 2270, Output: 12
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 31553da4-d934-4a5a-9fe4-618c86111111
# [logging_plugin]    Author: reader_profile_agent
# [logging_plugin]    Content: function_call: get_user_preferences
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['get_user_preferences']
# [7] reader_profile_agent
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: get_user_preferences
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    Function Call ID: adk-379e0455-b0c6-462c-97e0-5185eb6c10fd
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: get_user_preferences
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    Function Call ID: adk-379e0455-b0c6-462c-97e0-5185eb6c10fd
# [logging_plugin]    Result: {"found": true, "preferences": {"budget": "moderate", "preferred_pace": "relaxed", "prefers_museums": true, "travels_with_kids": false}}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d2d389d8-08a2-4047-ba36-f4ca5eb88206
# [logging_plugin]    Author: reader_profile_agent
# [logging_plugin]    Content: function_response: get_user_preferences
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['get_user_preferences']
# [8] reader_profile_agent
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    System Instruction: 'You are a reader profile specialist focused on personalization.
#
# FIRST, call the get_user_preferences tool to retrieve user preferences from session state.
#
# The preferences may include:
# - budget: "bud...'
# [logging_plugin]    Available Tools: ['get_user_preferences']
# 2025-11-25 16:44:50 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:52 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: reader_profile_agent
# [logging_plugin]    Content: text: 'User prefers moderate budget, relaxed pace, does like museums.'
# [logging_plugin]    Token Usage - Input: 2340, Output: 12
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ffc0b150-36ee-49a8-a347-6951691e7998
# [logging_plugin]    Author: reader_profile_agent
# [logging_plugin]    Content: text: 'User prefers moderate budget, relaxed pace, does like museums.'
# [logging_plugin]    Final Response: True
# [9] reader_profile_agent
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: reader_profile_agent
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: parallel_discovery
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: city_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.city_pipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: city_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.city_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: city_researcher
# [logging_plugin]    System Instruction: 'You are a literary travel specialist. Find real cities readers can visit.
#
# Based on the book's setting from the conversation history, use google_search to find:
#
# 1. SETTING CITIES: Actual cities where...'
# 2025-11-25 16:44:52 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:52 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: landmark_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.landmark_pipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: landmark_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.landmark_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: landmark_researcher
# [logging_plugin]    System Instruction: 'You are a landmark research specialist. Find specific places to visit.
#
# Based on the book and cities from the conversation history, use google_search to find:
#
# 1. MENTIONED LANDMARKS: Specific buildin...'
# 2025-11-25 16:44:52 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:52 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: author_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.author_pipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: author_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.author_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: author_researcher
# [logging_plugin]    System Instruction: 'You are an author biography specialist. Find places connected to the author.
#
# Based on the author from the conversation history, use google_search to find:
#
# 1. AUTHOR'S HOMETOWN: Where was the author ...'
# 2025-11-25 16:44:52 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:44:52 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:00 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: author_researcher
# [logging_plugin]    Content: text: 'Here are several significant sites connected to Jane Austen, the author of "Pride and Prejudice," grouped by practical travel regions:
#
# ### **Hampshire Region**
#
# This region is central to Jane Austen'...'
# [logging_plugin]    Token Usage - Input: 2295, Output: 912
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cb2c8a81-5ba5-4e62-a62c-a821ce9a0f49
# [logging_plugin]    Author: author_researcher
# [logging_plugin]    Content: text: 'Here are several significant sites connected to Jane Austen, the author of "Pride and Prejudice," grouped by practical travel regions:
#
# ### **Hampshire Region**
#
# This region is central to Jane Austen'...'
# [logging_plugin]    Final Response: True
# [10] author_researcher
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: author_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: author_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.author_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: author_formatter
# [logging_plugin]    System Instruction: 'Format the author sites into validated AuthorSites.
#
# IMPORTANT: If the research found no author sites, return an empty list - do not hallucinate.
#
# For each site found, create an AuthorSiteInfo with:
# -...'
# 2025-11-25 16:45:00 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:45:00 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:03 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: city_researcher
# [logging_plugin]    Content: text: 'Here are several real cities and locations connected to Jane Austen's "Pride and Prejudice," offering literary travelers a chance to step into the world of Elizabeth Bennet and Mr. Darcy:
#
# **1. Derbys...'
# [logging_plugin]    Token Usage - Input: 2281, Output: 739
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 705b35f8-0804-4c8f-bfa3-74f7004a577e
# [logging_plugin]    Author: city_researcher
# [logging_plugin]    Content: text: 'Here are several real cities and locations connected to Jane Austen's "Pride and Prejudice," offering literary travelers a chance to step into the world of Elizabeth Bennet and Mr. Darcy:
#
# **1. Derbys...'
# [logging_plugin]    Final Response: True
# [11] city_researcher
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: city_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: city_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.city_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: city_formatter
# [logging_plugin]    System Instruction: 'Format the cities into validated CityDiscovery.
#
# IMPORTANT: If the research found no cities, return an empty list - do not hallucinate.
#
# For each city found, create a CityInfo with:
# - name: City name ...'
# 2025-11-25 16:45:03 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:45:03 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:05 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: author_formatter
# [logging_plugin]    Content: text: '{"author_sites": [{"name": "Jane Austen's House", "type": "museum", "city": "Chawton"}, {"name": "Steventon (Birthplace)", "type": "birthplace", "city": "Steventon"}, {"name": "Winchester Cathedral", ...'
# [logging_plugin]    Token Usage - Input: 3095, Output: 180
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0de78193-d487-47de-8acb-0f37625ef471
# [logging_plugin]    Author: author_formatter
# [logging_plugin]    Content: text: '{"author_sites": [{"name": "Jane Austen's House", "type": "museum", "city": "Chawton"}, {"name": "Steventon (Birthplace)", "type": "birthplace", "city": "Steventon"}, {"name": "Winchester Cathedral", ...'
# [logging_plugin]    Final Response: True
# [12] author_formatter
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: author_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: author_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# 2025-11-25 16:45:07 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: landmark_researcher
# [logging_plugin]    Content: text: 'Here are several specific places to visit that connect to "Pride and Prejudice" by Jane Austen, encompassing mentioned landmarks, themed experiences, and atmospheric locations:
#
# **Derbyshire Region**
# ...'
# [logging_plugin]    Token Usage - Input: 2295, Output: 1029
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4233ae5f-6714-4847-810a-67c0ec6ba433
# [logging_plugin]    Author: landmark_researcher
# [logging_plugin]    Content: text: 'Here are several specific places to visit that connect to "Pride and Prejudice" by Jane Austen, encompassing mentioned landmarks, themed experiences, and atmospheric locations:
#
# **Derbyshire Region**
# ...'
# [logging_plugin]    Final Response: True
# [13] landmark_researcher
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: landmark_researcher
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: landmark_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Branch: parallel_discovery.landmark_pipeline
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: landmark_formatter
# [logging_plugin]    System Instruction: 'Format the landmarks into validated LandmarkDiscovery.
#
# IMPORTANT: If the research found no landmarks, return an empty list - do not hallucinate.
#
# For each landmark found, create a LandmarkInfo with:
# ...'
# 2025-11-25 16:45:07 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:45:07 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:10 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: landmark_formatter
# [logging_plugin]    Content: text: '{"landmarks":[{"name":"Chatsworth House","city":"Bakewell, Derbyshire","connection":"Widely believed to be the inspiration for Mr. Darcy's magnificent estate, Pemberley, and explicitly mentioned in th...'
# [logging_plugin]    Token Usage - Input: 3160, Output: 428
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1f61f0a6-8201-4747-bf03-790cf89f7864
# [logging_plugin]    Author: landmark_formatter
# [logging_plugin]    Content: text: '{"landmarks":[{"name":"Chatsworth House","city":"Bakewell, Derbyshire","connection":"Widely believed to be the inspiration for Mr. Darcy's magnificent estate, Pemberley, and explicitly mentioned in th...'
# [logging_plugin]    Final Response: True
# [14] landmark_formatter
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: landmark_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: landmark_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# 2025-11-25 16:45:15 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: city_formatter
# [logging_plugin]    Content: text: '{
#   "cities": []
# }'
# [logging_plugin]    Token Usage - Input: 2901, Output: 9
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5f681bea-ff49-4bd0-a983-b7eedad2498b
# [logging_plugin]    Author: city_formatter
# [logging_plugin]    Content: text: '{
#   "cities": []
# }'
# [logging_plugin]    Final Response: True
# [15] city_formatter
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: city_formatter
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: city_pipeline
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: parallel_discovery
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: region_analyzer
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: region_analyzer
# [logging_plugin]    System Instruction: 'You are a travel logistics expert. Analyze discovered cities and group them into PRACTICAL TRAVEL REGIONS.
#
# ## Your Task
#
# Review the discovered cities, landmarks, and author sites from the conversatio...'
# 2025-11-25 16:45:15 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:45:15 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:37 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: region_analyzer
# [logging_plugin]    Content: text: '{
#   "regions": [
#     {
#       "region_id": 1,
#       "region_name": "Hampshire - Jane Austen's Heartlands",
#       "cities": [
#         {
#           "name": "Chawton",
#           "country": "England"
#       ...'
# [logging_plugin]    Token Usage - Input: 5840, Output: 1188
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5318f4bf-5d31-4535-8ee8-ea16511fc723
# [logging_plugin]    Author: region_analyzer
# [logging_plugin]    Content: text: '{
#   "regions": [
#     {
#       "region_id": 1,
#       "region_name": "Hampshire - Jane Austen's Heartlands",
#       "cities": [
#         {
#           "name": "Chawton",
#           "country": "England"
#       ...'
# [logging_plugin]    Final Response: True
# [16] region_analyzer
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: region_analyzer
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: discovery_workflow
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-ce69d125-07d1-4152-8437-d5549cf753ca
# [logging_plugin]    Final Agent: discovery_workflow
#
# ✅ Discovery complete!
#    Regions found: 5

# %% [markdown]
# ### Human-in-the-Loop: Region Selection
#
# Display region options and let the user select which to explore.

# %%
print("="*70)
print("TRAVEL REGION OPTIONS")
print("="*70)

regions = region_analysis.get("regions", [])

if not regions:
    print("\n⚠️  No regions found. Using all discovered cities.")
    selected_regions = []  # Will use all cities
else:
    print(f"\n{region_analysis.get('summary', 'Cities grouped by geographic proximity.')}\n")
    
    for i, region in enumerate(regions, 1):
        print(f"[{i}] {region.get('region_name')}")
        
        cities = region.get('cities', [])
        city_names = [c.get('name') for c in cities if c.get('name')]
        print(f"    Cities: {', '.join(city_names)}")
        
        if region.get('estimated_days'):
            print(f"    Duration: ~{region.get('estimated_days')} days")
        
        if region.get('travel_note'):
            print(f"    Travel: {region.get('travel_note')}")
        
        if region.get('highlights'):
            highlights = region.get('highlights')[:2] if isinstance(region.get('highlights'), list) else [region.get('highlights')]
            print(f"    Highlights: {', '.join(highlights)}")
        
        print()
    
    # For demo purposes, auto-select the first region
    # In a real notebook, you'd use: input("Which region(s)? ")
    print("📝 For this demo, auto-selecting region #1\n")
    selected_regions = [regions[0]]  # Select first region
    
    print(f"✅ Selected: {selected_regions[0].get('region_name')}")

# Validate that we have regions to work with
if not selected_regions:
    error_msg = (
        "No regions available to create an itinerary. "
        "The discovery phase did not find enough locations to group into travel regions. "
        "Try a different book or check the discovery results."
    )
    print(f"\n❌ Error: {error_msg}")
    raise ValueError(error_msg)

# Store selected regions in session state for trip_composer to access
session = await session_service.get_session(
    app_name="storyland", user_id=user_id, session_id=session_id
)
session.state["selected_regions"] = selected_regions

print(f"\n💾 Stored {len(selected_regions)} region(s) in session state")
# Out:
# ======================================================================
# TRAVEL REGION OPTIONS
# ======================================================================
#
# Cities grouped by geographic proximity.
#
# [1] Hampshire - Jane Austen's Heartlands
#     Cities: Chawton, Steventon, Winchester
#     Duration: ~3 days
#     Travel: All locations are within Hampshire and easily accessible by car, with short drives (30-45 minutes) between cities.
#     Highlights: Explore Jane Austen's actual home and writing place, her birthplace site, her family's manor, and her final resting place in Winchester Cathedral. This region offers the deepest personal connection to the author.
#
# [2] North Midlands - Pemberley & Peak District
#     Cities: Bakewell, Sudbury, Disley, Peak District National Park
#     Duration: ~4 days
#     Travel: Travel by car is recommended to navigate between the stately homes and scenic Peak District locations, with drives typically 1-1.5 hours.
#     Highlights: Visit iconic 'Pemberley' film locations like Chatsworth House (2005 film) and Lyme Park (1995 BBC series), explore Sudbury Hall for interior shots, and experience the natural beauty of Stanage Edge, where Elizabeth Bennet contemplated.
#
# [3] Southern England - Film Locations & Regency Charm
#     Cities: Bath, Reading, Lacock, Wilton
#     Duration: ~4 days
#     Travel: A rental car is ideal for visiting the dispersed film locations. Bath is well-connected by train, and local buses can supplement car travel. Drives between cities range from 30 minutes to 1.5 hours.
#     Highlights: Immerse yourself in Regency-era life at The Jane Austen Centre in historic Bath, see Basildon Park (Netherfield in 2005 film), wander through Lacock Village (Meryton in 1995 series), and visit Wilton House for more 'Pemberley' interiors.
#
# [4] London & Kent - Capital & Country Estates
#     Cities: London, Groombridge
#     Duration: ~4 days
#     Travel: London offers extensive public transport. Groombridge Place can be visited as a day trip from London by train and taxi/local bus or by car (approx. 1 hour 15 min drive).
#     Highlights: Pay respects to Jane Austen's memorial in Westminster Abbey's Poet's Corner. Take a day trip to Groombridge Place, the picturesque manor that served as the Bennet family's Longbourn in the 2005 film adaptation.
#
# [5] East Midlands - Rosings Park
#     Cities: Stamford
#     Duration: ~2 days
#     Travel: Travel to Stamford by train or car. A car is recommended for visiting Burghley House from Stamford town, or a local taxi. Drives are short within the area.
#     Highlights: Discover Burghley House, the imposing and luxurious estate used for Lady Catherine de Bourgh's Rosings Park in the 2005 film, and explore the charming Georgian town of Stamford, which also featured in the movie.
#
# 📝 For this demo, auto-selecting region #1
#
# ✅ Selected: Hampshire - Jane Austen's Heartlands
#
# 💾 Stored 1 region(s) in session state

# %% [markdown]
# ### Phase 3: Create Personalized Itinerary

# %%
print("="*70)
print("PHASE 3: CREATE PERSONALIZED ITINERARY")
print("="*70)

# Create composition workflow
composition_workflow = create_composition_workflow(model)

composition_runner = Runner(
    agent=composition_workflow,
    app_name="storyland",
    session_service=session_service,
    plugins=[LoggingPlugin()],
)

composition_prompt = f"""Create a personalized literary travel itinerary for "{exact_title}" by {exact_author}.

Use ONLY the cities from the selected region(s): {json.dumps(selected_regions)}

Create a personalized itinerary based on user preferences and the selected region(s).
Include ALL cities from the selected regions in your itinerary."""

composition_message = types.Content(role="user", parts=[types.Part(text=composition_prompt)])

print(f"\n📝 Prompt: Create itinerary for selected region(s)")
print(f"\n🔄 Executing composition...\n")

final_response = None
async with composition_runner:
    async for event in composition_runner.run_async(
        user_id=user_id, session_id=session_id, new_message=composition_message
    ):
        event_count += 1
        if event.author:
            print(f"[{event_count}] {event.author}")
        if event.is_final_response():
            final_response = event

print(f"\n✅ Itinerary created! ({event_count} total events)")
# Out:
# ======================================================================
# PHASE 3: CREATE PERSONALIZED ITINERARY
# ======================================================================
# 2025-11-25 16:45:37 - google_adk.google.adk.plugins.plugin_manager - INFO - Plugin 'logging_plugin' registered.
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - App name mismatch detected. The runner is configured with app name "storyland", but the root agent was loaded from "/Users/osa/Documents/storyland/storyland-ai/.venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
#
# 📝 Prompt: Create itinerary for selected region(s)
#
# 🔄 Executing composition...
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin]    Session ID: d1545072-e8e2-4719-b94e-7a496081bcb4
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: storyland
# [logging_plugin]    Root Agent: composition_workflow
# [logging_plugin]    User Content: text: 'Create a personalized literary travel itinerary for "Pride and Prejudice" by Jane Austen.
#
# Use ONLY the cities from the selected region(s): [{"region_id": 1, "region_name": "Hampshire - Jane Austen's ...'
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: region_analyzer, event id: 5318f4bf-5d31-4535-8ee8-ea16511fc723
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: landmark_formatter, event id: 1f61f0a6-8201-4747-bf03-790cf89f7864
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: city_formatter, event id: 5f681bea-ff49-4bd0-a983-b7eedad2498b
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: author_formatter, event id: 0de78193-d487-47de-8acb-0f37625ef471
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: author_researcher, event id: cb2c8a81-5ba5-4e62-a62c-a821ce9a0f49
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: landmark_researcher, event id: 4233ae5f-6714-4847-810a-67c0ec6ba433
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: city_researcher, event id: 705b35f8-0804-4c8f-bfa3-74f7004a577e
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: reader_profile_agent, event id: ffc0b150-36ee-49a8-a347-6951691e7998
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: reader_profile_agent, event id: d2d389d8-08a2-4047-ba36-f4ca5eb88206
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: reader_profile_agent, event id: 31553da4-d934-4a5a-9fe4-618c86111111
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_context_formatter, event id: feb7346a-f3df-481b-86b3-b2b4ab27a07c
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_context_researcher, event id: 94a7561a-39bd-4a6d-aa84-61bf957fe93d
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_formatter, event id: 05951a55-0545-4049-9b54-83e5a877ca68
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 4e159bb5-97f0-4a27-bdf1-78aae01bb604
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 9d4b74c4-3ca5-47da-8809-77dee7efacc1
# 2025-11-25 16:45:37 - google_adk.google.adk.runners - WARNING - Event from an unknown agent: book_metadata_researcher, event id: 129dc74f-6836-4b7f-a7bf-8a09e3b37ae8
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin]    Starting Agent: composition_workflow
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: composition_workflow
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: trip_composer
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: trip_composer
# [logging_plugin]    System Instruction: 'You are a literary travel planner. Create a PERSONALIZED travel itinerary.
#
# ## Step 1: Check for Selected Region (IMPORTANT!)
#
# Look for "selected_region" in the conversation history. This contains the...'
# 2025-11-25 16:45:37 - google_adk.google.adk.models.google_llm - INFO - Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 16:45:37 - google_genai.models - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-25 16:45:54 - google_adk.google.adk.models.google_llm - INFO - Response received from the model.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: trip_composer
# [logging_plugin]    Content: text: '{
#   "cities": [
#     {
#       "name": "Chawton",
#       "country": "England",
#       "days_suggested": 1,
#       "overview": "Immerse yourself in the very home where Jane Austen lived and revised 'Pride an...'
# [logging_plugin]    Token Usage - Input: 7418, Output: 1276
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d287ecc2-886d-4e31-80a3-9f650bac64c5
# [logging_plugin]    Author: trip_composer
# [logging_plugin]    Content: text: '{
#   "cities": [
#     {
#       "name": "Chawton",
#       "country": "England",
#       "days_suggested": 1,
#       "overview": "Immerse yourself in the very home where Jane Austen lived and revised 'Pride an...'
# [logging_plugin]    Final Response: True
# [17] trip_composer
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: trip_composer
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: composition_workflow
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-0e304ba9-8eda-42b6-8e2c-bd6507c01e2d
# [logging_plugin]    Final Agent: composition_workflow
#
# ✅ Itinerary created! (17 total events)

# %% [markdown]
# ## 🎉 Section 10: Display Final Itinerary
#
# Parse and display the complete travel plan.

# %%
# Get final itinerary from session state
session = await session_service.get_session(
    app_name="storyland", user_id=user_id, session_id=session_id
)
itinerary = session.state.get("final_itinerary", {})

print("="*70)
print(f"LITERARY TRAVEL ITINERARY")
print(f"{exact_title} by {exact_author}")
print("="*70)

# Display summary
if itinerary.get("summary_text"):
    print(f"\n📖 {itinerary['summary_text']}\n")

# Display cities
cities = itinerary.get("cities", [])
if cities:
    print(f"\n🌍 {len(cities)} {'City' if len(cities) == 1 else 'Cities'} to Visit:")
    print("="*70)
    
    for i, city in enumerate(cities, 1):
        print(f"\n{i}. {city.get('name')}, {city.get('country')}")
        print(f"   Days: {city.get('days_suggested')}")
        
        if city.get('overview'):
            print(f"   {city['overview']}")
        
        stops = city.get('stops', [])
        if stops:
            print(f"\n   📍 {len(stops)} Stops:")
            for j, stop in enumerate(stops, 1):
                print(f"\n      {j}. {stop.get('name')} [{stop.get('type')}]")
                print(f"         Time: {stop.get('time_of_day', 'any time').upper()}")
                print(f"         Why: {stop.get('reason')}")
                if stop.get('notes'):
                    print(f"         💡 {stop.get('notes')}")

    # Statistics
    total_days = sum(c.get('days_suggested', 0) for c in cities)
    total_stops = sum(len(c.get('stops', [])) for c in cities)
    
    print("\n" + "="*70)
    print("📊 TRIP STATISTICS")
    print("="*70)
    print(f"   Total cities: {len(cities)}")
    print(f"   Total days: {total_days}")
    print(f"   Total stops: {total_stops}")
    print(f"   Budget: {USER_PREFERENCES.get('budget', 'N/A')}")
    print(f"   Pace: {USER_PREFERENCES.get('preferred_pace', 'N/A')}")
else:
    print("\n⚠️  No itinerary data found.")
# Out:
# ======================================================================
# LITERARY TRAVEL ITINERARY
# Pride and Prejudice by Jane Austen
# ======================================================================
#
# 📖 This personalized itinerary guides you through 'Hampshire - Jane Austen's Heartlands,' offering a relaxed and deeply immersive journey into the life and inspiration of Jane Austen. As a museum enthusiast with a moderate budget, you'll delve into the intimate details of her homes in Chawton and Steventon, culminating in a respectful visit to her final resting place in Winchester Cathedral. Expect leisurely days filled with literary discovery, perfectly paced for reflection and enjoyment of England's charming countryside.
#
#
# 🌍 3 Cities to Visit:
# ======================================================================
#
# 1. Chawton, England
#    Days: 1
#    Immerse yourself in the very home where Jane Austen lived and revised 'Pride and Prejudice.' Chawton offers an intimate glimpse into her daily life and the literary world she created.
#
#    📍 3 Stops:
#
#       1. Jane Austen's House Museum [museum]
#          Time: FULL_DAY
#          Why: This is Jane Austen's final home where she lived from 1809 until 1817, revising 'Pride and Prejudice' and writing her other major novels. It offers the deepest personal connection to her writing process.
#          💡 Plan for a significant portion of the day here. As you prefer museums, allow ample time to explore the rooms, personal artifacts, and first editions. There is an admission fee, which fits a moderate budget.
#
#       2. Chawton House [historic house]
#          Time: AFTERNOON
#          Why: This Elizabethan manor belonged to Jane Austen's brother, Edward, and she was a frequent visitor. It now houses a research library focusing on early women's writing, offering atmospheric insights into her world.
#          💡 Located a short walk from Jane Austen's House, Chawton House offers beautiful gardens and a fascinating library. There is an admission fee, but it's a valuable stop for literary enthusiasts.
#
#       3. St. Nicholas Churchyard & Jane Austen Statue [landmark]
#          Time: MORNING
#          Why: Visit the church that Jane Austen attended during her time in Chawton and see the modern bronze statue of the author, reflecting her enduring legacy.
#          💡 This is a brief, reflective stop. The churchyard is a peaceful place for a stroll, and the statue provides a nice photo opportunity. Free to visit.
#
# 2. Steventon, England
#    Days: 1
#    Journey to Jane Austen's birthplace, a quiet village where she spent her formative years and began crafting her initial stories, including early drafts of 'Pride and Prejudice.'
#
#    📍 2 Stops:
#
#       1. St. Nicholas Church, Steventon [historic church]
#          Time: MORNING
#          Why: Jane Austen's father was the rector here, and she and her family attended services throughout her childhood. It's one of the few remaining structures directly connected to her early life.
#          💡 The church remains largely as it was in Austen's time. Enjoy a quiet moment of reflection. Free to enter, donations welcome.
#
#       2. Site of Steventon Rectory [historic site]
#          Time: AFTERNOON
#          Why: Although the original rectory where Jane Austen was born and wrote the first drafts of her novels no longer stands, the site is marked by a lime tree said to have been planted by her brother. It's a place for quiet contemplation of her beginnings.
#          💡 This is a site for imaginative reflection rather than a physical building. Enjoy the peaceful countryside walk to reach it. Free to visit.
#
# 3. Winchester, England
#    Days: 1
#    Explore the historic city of Winchester, the final resting place of Jane Austen, where you can pay your respects at her memorial within the grand Cathedral and soak in the Georgian atmosphere.
#
#    📍 2 Stops:
#
#       1. Winchester Cathedral [cathedral]
#          Time: FULL_DAY
#          Why: This magnificent historic cathedral is the final resting place of Jane Austen, whose memorial stone and later brass plaque commemorate her literary achievements. It's a poignant stop for any Austen admirer.
#          💡 Allocate a good amount of time to explore the cathedral's rich history and architecture, beyond just Austen's grave. There is an admission fee, which is appropriate for a moderate budget traveler who appreciates museums.
#
#       2. Exploring Historic Winchester City Centre [city exploration]
#          Time: AFTERNOON
#          Why: Winchester, with its ancient streets and Georgian architecture, would have been familiar to Jane Austen in her final days. A stroll through the city offers a feel for the period that shaped her novels.
#          💡 Enjoy a leisurely walk through the city's charming streets, perhaps visit the Great Hall, and find a cozy spot for afternoon tea or a moderate-priced meal. This is a free activity, aligning with a moderate budget.
#
# ======================================================================
# 📊 TRIP STATISTICS
# ======================================================================
#    Total cities: 3
#    Total days: 3
#    Total stops: 7
#    Budget: moderate
#    Pace: relaxed

# %% [markdown]
# ## 📊 Section 11: Session Statistics
#
# Check session state and context usage.

# %%
# Get final session state
final_session = await session_service.get_session(
    app_name="storyland", user_id=user_id, session_id=session_id
)

print("📊 SESSION STATISTICS")
print("="*70)
print(f"   User ID: {user_id}")
print(f"   Session ID: {session_id[:8]}...")
print(f"   Total events: {len(final_session.events)}")

# Show state keys
state_keys = list(final_session.state.keys())
print(f"\n   State keys ({len(state_keys)}):")
for key in state_keys:
    if key.startswith("user:"):
        print(f"     - {key} (user-scoped, persists)")
    else:
        print(f"     - {key} (session-scoped)")

# Context statistics
stats = context_manager.get_context_stats(final_session.events)
print(f"\n   Context:")
print(f"     Total characters: {stats['total_chars']:,}")
print(f"     Estimated tokens: ~{stats['estimated_tokens']:,}")
print(f"     Within limit: {stats['within_limit']}")
# Out:
# 📊 SESSION STATISTICS
# ======================================================================
#    User ID: demo_user
#    Session ID: d1545072...
#    Total events: 20
#
#    State keys (9):
#      - book_metadata (session-scoped)
#      - book_context (session-scoped)
#      - reader_profile (session-scoped)
#      - author_sites (session-scoped)
#      - landmark_discovery (session-scoped)
#      - city_discovery (session-scoped)
#      - region_analysis (session-scoped)
#      - final_itinerary (session-scoped)
#      - user:preferences (user-scoped, persists)
#
#    Context:
#      Total characters: 31,261
#      Estimated tokens: ~7,815
#      Within limit: True

# %% [markdown]
# ## 🎓 Summary
#
# Congratulations! You've just executed a complete multi-agent literary travel planning system.
#
# ### ✅ Features You Experienced:
#
# #### Multi-Agent Architecture
# - Sequential agents (metadata → discovery → composition)
# - Parallel agents (concurrent city/landmark/author discovery)
# - Three-phase workflow with HITL region selection
#
# #### Tools & Integration
# - Custom tools (Google Books API, preferences)
# - Built-in tools (Google Search)
# - Pydantic models for type-safe communication
#
# #### Sessions & State
# - Database-backed sessions (SQLite)
# - Multi-scoped state (session, user, app, temp)
# - User preferences persisting across sessions
#
# #### Context Engineering
# - Context manager for size monitoring
# - Token estimation and event limiting
#
# #### Observability
# - Structured logging (structlog)
# - ADK LoggingPlugin
# - Event tracking and monitoring
#
# #### Evaluation
# - ADK eval with custom rubrics
# - Automated testing framework
#
# ---
#
# ## 🚀 Next Steps
#
# ### Try These:
#
# 1. **Change the book** - Edit `BOOK_TITLE` and `AUTHOR` above and re-run
# 2. **Customize preferences** - Modify `USER_PREFERENCES` (budget, pace, museums, kids)
# 3. **Select different regions** - Choose different region numbers when prompted
# 4. **Use the CLI** - Try `python main.py "Book Title" --budget luxury --pace relaxed`
# 5. **Run evaluations** - Execute ADK eval with `adk eval agents/storyland single_test`
# 6. **Query the database** - Use SQL to analyze user sessions and preferences
# 7. **Add new agents** - Create custom agents in `agents/` directory
# 8. **Add new tools** - Build custom tools in `tools/` directory
#
# ### Learn More:
#
# - **Google ADK Docs**: https://ai.google.dev/adk
# - **Project README**: [README.md](README.md)
# - **Agent Code**: [agents/orchestrator.py](agents/orchestrator.py)
# - **Models**: [models/](models/) directory
# - **Tests**: [tests/unit/](tests/unit/) directory
#
# ---
#
# ## 📝 CLI Quick Reference
#
# ```bash
# # Basic usage
# python main.py "Pride and Prejudice"
#
# # With preferences
# python main.py "Gone with the Wind" --budget luxury --pace fast-paced
#
# # With author
# python main.py "1984" --author "George Orwell"
#
# # With database persistence
# python main.py "Harry Potter" --database
#
# # Family trip
# python main.py "Harry Potter" --with-kids --budget moderate
#
# # Run tests
# .venv/bin/pytest tests/unit/ -v
#
# # Run evaluation
# .venv/bin/adk eval agents/storyland single_test \
#   --config_file_path tests/evaluation/eval_config.json
#
# # ADK Web UI
# .venv/bin/adk web agents/storyland
# ```
#
# ---
#
# *Built with Google Agent Development Kit* 🤖
